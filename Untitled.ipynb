# %% [markdown]
# # Mod 4 - Natural Language Processing Project
#
# Please fill out:
# * Student name: Max Steele
# * Student pace: Full Time
# * Scheduled project review date/time:
# * Instructor name: James Irving
# * Blog post URL: <a href=""></a>

# %% [markdown]
# <font size=3rem>
#
# - **[Introduction](#Introduction)<br>**
# - **[OBTAIN](#OBTAIN)**<br>
# - **[SCRUB](#SCRUB)**<br>
# - **[EXPLORE](#EXPLORE)**<br>
# - **[MODEL](#MODEL)**<br>
# - **[INTERPRET](#INTERPRET)**<br>
# - **[Conclusions/Recommendations](#Conclusions/Recommendations)<br>**
# </font>

# %% [markdown]
# # Introduction

# %% [markdown]
# # OBTAIN

# %%
import numpy as np
np.random.seed(319)

# %%
from project_functions import *

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
## Import and preview dataset
full_df = pd.read_csv('Data/orig_labeled_data.csv', index_col=0)
full_df.head()
# Out:
#    count  hate_speech  offensive_language  neither  class  \
# 0      3            0                   0        3      2
# 1      3            0                   3        0      1
# 2      3            0                   3        0      1
# 3      3            0                   2        1      1
# 4      6            0                   6        0      1
#
#                                                tweet
# 0  !!! RT @mayasolovely: As a woman you shouldn't...
# 1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...

# %%
## View info for records and columns
full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24783 entries, 0 to 25296
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   count               24783 non-null  int64
#  1   hate_speech         24783 non-null  int64
#  2   offensive_language  24783 non-null  int64
#  3   neither             24783 non-null  int64
#  4   class               24783 non-null  int64
#  5   tweet               24783 non-null  object
# dtypes: int64(5), object(1)
# memory usage: 1.3+ MB

# %%
## Drop unnecessary columns
full_df = full_df.drop(columns=['count', 'hate_speech', 'offensive_language', 'neither'], axis=1)
full_df.head()
# Out:
#     class                                              tweet
# 0       2  !!! RT @mayasolovely: As a woman you shouldn't...
# 1       1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2       1  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3       1  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4       1  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
# 5       1  !!!!!!!!!!!!!!!!!!"@T_Madison_x: The shit just...
# 6       1  !!!!!!"@__BrighterDays: I can not just sit up ...
# 7       1  !!!!&#8220;@selfiequeenbri: cause I'm tired of...
# 8       1  " &amp; you might not get ya bitch back &amp; ...
# 9       1  " @rhythmixx_ :hobbies include: fighting Maria...
# 10      1  " Keeks is a bitch she curves everyone " lol I...
# 11      1                 " Murda Gang bitch its Gang Land "
# 12      1  " So hoes that smoke are losers ? " yea ... go...
# 13      1      " bad bitches is the only thing that i like "
# 14      1                            " bitch get up off me "

# %%
## Replace number codes with class names to make things easier to keep track of
# Create a dict of values to be mapped
class_dict = {0: 'hate speech', 1: 'offensive', 2: 'neither'}

# Replace keys (0, 1, and 2) with corresponding values and preview dataset
full_df['class'] = full_df['class'].map(class_dict)
full_df.head()
# Out:
#         class                                              tweet
# 0     neither  !!! RT @mayasolovely: As a woman you shouldn't...
# 1   offensive  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2   offensive  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3   offensive  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4   offensive  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
# 5   offensive  !!!!!!!!!!!!!!!!!!"@T_Madison_x: The shit just...
# 6   offensive  !!!!!!"@__BrighterDays: I can not just sit up ...
# 7   offensive  !!!!&#8220;@selfiequeenbri: cause I'm tired of...
# 8   offensive  " &amp; you might not get ya bitch back &amp; ...
# 9   offensive  " @rhythmixx_ :hobbies include: fighting Maria...
# 10  offensive  " Keeks is a bitch she curves everyone " lol I...
# 11  offensive                 " Murda Gang bitch its Gang Land "
# 12  offensive  " So hoes that smoke are losers ? " yea ... go...
# 13  offensive      " bad bitches is the only thing that i like "
# 14  offensive                            " bitch get up off me "

# %%
## Print value counts and percentages of classes for full dataset
check_unique(full_df, 'class') 
# Note: pretty extreme imbalance of classes
# Out:
#              count         %
# offensive    19190  0.774321
# neither       4163  0.167978
# hate speech   1430  0.057701

# %%
## Print value counts and percentages of tweets for full dataset
check_unique(full_df, 'tweet') # Each tweet only shows up once
# Out:
#                                                     count        %
# @Godsmack_Music @iTunesMusic @iTunes That band ...      1  0.00004
# #TweetLikeYourBestfriend "I made out with 3 bit...      1  0.00004
# Im about to get all the pussy.                          1  0.00004
# RT @fart: My friends the 2014 @Chevrolet Malibu...      1  0.00004
# Went ya bitch house now she not a virgin anymore        1  0.00004
# ...                                                   ...      ...
# RT @RayHudson: Art thou the bird whom Man loves...      1  0.00004
# @ZitlalyL You will and he's gonna get all dem b...      1  0.00004
# Ma bottom bitch cotton pick if I tell her too ,...      1  0.00004
# RT @If_ItAint_B: Miami isn't a good city at all...      1  0.00004
# Every slant in #LosAngeles should be deported. ...      1  0.00004
#
# [24783 rows x 2 columns]

# %%
## Create df of all hate speech tweets
hate_df = full_df.groupby('class').get_group('hate speech')
hate_df.head()
# Out:
#            class                                              tweet
# 85   hate speech  "@Blackman38Tide: @WhaleLookyHere @HowdyDowdy1...
# 90   hate speech  "@CB_Baby24: @white_thunduh alsarabsss" hes a ...
# 111  hate speech  "@DevilGrimz: @VigxRArts you're fucking gay, b...
# 186  hate speech  "@MarkRoundtreeJr: LMFAOOOO I HATE BLACK PEOPL...
# 204  hate speech  "@NoChillPaz: "At least I'm not a nigger" http...

# %%
## Create df of all offensive tweets
offensive_df = full_df.groupby('class').get_group('offensive')
offensive_df.head()
# Out:
#        class                                              tweet
# 1  offensive  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2  offensive  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3  offensive  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4  offensive  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
# 5  offensive  !!!!!!!!!!!!!!!!!!"@T_Madison_x: The shit just...

# %%
## Create df of a subset of offensive tweets (concatenate with other classes to address class imbalance)
offensive_df_subset = offensive_df.sample(4407, random_state=319)
offensive_df_subset.head()
# Out:
#            class                                              tweet
# 22117  offensive  Them quicc to blast bitches, them all about th...
# 8265   offensive  Bitch and who the fuck r u am speak when the f...
# 20786  offensive  RT @woohdakidd_74: @Shane_A1 &#128514;&#128514...
# 4598   offensive  @RBesofii \nCants even fool a colored man wit ...
# 21540  offensive  Sometimes females are just fucking retarded br...

# %%
## Create df of neither hate speech nor offensive tweets
neither_df = full_df.groupby('class').get_group('neither')
neither_df.head()
# Out:
#       class                                              tweet
# 0   neither  !!! RT @mayasolovely: As a woman you shouldn't...
# 40  neither    " momma said no pussy cats inside my doghouse "
# 63  neither  "@Addicted2Guys: -SimplyAddictedToGuys http://...
# 66  neither  "@AllAboutManFeet: http://t.co/3gzUpfuMev" woo...
# 67  neither  "@Allyhaaaaa: Lemmie eat a Oreo &amp; do these...

# %%
df = pd.concat([hate_df, offensive_df_subset, neither_df], axis=0)
df.reset_index(inplace=True, drop=True)
display(df.head())
df.info()
# Out:
#          class                                              tweet
# 0  hate speech  "@Blackman38Tide: @WhaleLookyHere @HowdyDowdy1...
# 1  hate speech  "@CB_Baby24: @white_thunduh alsarabsss" hes a ...
# 2  hate speech  "@DevilGrimz: @VigxRArts you're fucking gay, b...
# 3  hate speech  "@MarkRoundtreeJr: LMFAOOOO I HATE BLACK PEOPL...
# 4  hate speech  "@NoChillPaz: "At least I'm not a nigger" http...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   class   10000 non-null  object
#  1   tweet   10000 non-null  object
# dtypes: object(2)
# memory usage: 156.4+ KB

# %% [markdown]
# # SCRUB

# %%
import nltk
from nltk.corpus import stopwords
from nltk import word_tokenize, FreqDist
from nltk.collocations import *
from nltk import regexp_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.manifold import TSNE
import string
import re

# %%
test_str = """&#128514;&#128514;@The_Paradox: And ima steal; RT @80sbaby4life: @The_Paradox He a &amp; he's gone always be a hoe @BestProAdvice: The facts on tattoos...tattoo me..claim http://t.co/ZwnbhpDZ8e @CarelessOne92: @305MAYOR https://t.co/iND1vON4JH&#8221"""

# %%
## Define various parts of stop lists to use for cleaning tokenized tweets
# List of misspellings and shorthands that are equivalent to nltk's english stopwords
twitter_stops = ['bc', 'ima', "i'm", 'im', "i'll", "it'll", 'hav', "that's", 'dat', 'dats', 'u', 'da', 'n']

# Punctuation tokens to remove in addition to string.punctuation
more_punc = ['...', '“','”','...',"''",'’','``']

# Full list of all stop tokens (words and punctuation)
stopwords_list = stopwords.words('english') + list(string.punctuation) + twitter_stops + more_punc

# List of punctuation stop tokens
stoppunct_list = list(string.punctuation) + more_punc

# %%
"have" in stopwords_list
# Out:
# True

# %%
## Create new cols in df for tweets tokenized and cleaned to differing degrees
# Punctuation removed
df['tweet_clean'] = df['tweet'].apply(lambda x: clean_tweet(x, stoppunct_list))
# Stop words and punctuation removed
df['tweet_stopped'] = df['tweet'].apply(lambda x: clean_tweet(x, stopwords_list))
# Preview updated df
df.head()
# Out:
#          class                                              tweet  \
# 0  hate speech  "@Blackman38Tide: @WhaleLookyHere @HowdyDowdy1...
# 1  hate speech  "@CB_Baby24: @white_thunduh alsarabsss" hes a ...
# 2  hate speech  "@DevilGrimz: @VigxRArts you're fucking gay, b...
# 3  hate speech  "@MarkRoundtreeJr: LMFAOOOO I HATE BLACK PEOPL...
# 4  hate speech  "@NoChillPaz: "At least I'm not a nigger" http...
#
#                                          tweet_clean  \
# 0                                    [queer, gaywad]
# 1  [alsarabsss, hes, a, beaner, smh, you, can, te...
# 2  [you're, fucking, gay, blacklisted, hoe, holdi...
# 3  [lmfaoooo, i, hate, black, people, this, is, w...
# 4            [at, least, i'm, not, a, nigger, lmfao]
#
#                                        tweet_stopped
# 0                                    [queer, gaywad]
# 1  [alsarabsss, hes, beaner, smh, tell, hes, mexi...
# 2  [fucking, gay, blacklisted, hoe, holding, tehg...
# 3  [lmfaoooo, hate, black, people, there's, black...
# 4                             [least, nigger, lmfao]

# %% [markdown]
# # EXPLORE

# %%
from nltk import FreqDist
from wordcloud import WordCloud

# %%
## Create a variable "raw_corpus" containing all text
raw_corpus = df['tweet'].to_list()
raw_corpus[:10]
# Out:
# ['"@Blackman38Tide: @WhaleLookyHere @HowdyDowdy11 queer" gaywad',
#  '"@CB_Baby24: @white_thunduh alsarabsss" hes a beaner smh you can tell hes a mexican',
#  '"@DevilGrimz: @VigxRArts you\'re fucking gay, blacklisted hoe" Holding out for #TehGodClan anyway http://t.co/xUCcwoetmn',
#  '"@MarkRoundtreeJr: LMFAOOOO I HATE BLACK PEOPLE https://t.co/RNvD2nLCDR" This is why there\'s black people and niggers',
#  '"@NoChillPaz: "At least I\'m not a nigger" http://t.co/RGJa7CfoiT"\n\nLmfao',
#  '"@NotoriousBM95: @_WhitePonyJr_ Ariza is a snake and a coward" but at least he isn\'t a cripple like your hero Roach lmaoo',
#  '"@RTNBA: Drakes new shoes that will be released by Nike/Jordan.... Yes, there\'s glitter on the shoes http://t.co/QCtPLxHEXM" ....dudes a fag',
#  '"@TheoMaxximus: #GerrysHalloweenParty http://t.co/3ycrSrnjHc" Halloween was yesterday stupid nigger',
#  '"@ashlingwilde: @ItsNotAdam is bored supposed to be cute, you faggot?" Sometimes',
#  '"@bigbootybishopp: @white_thunduh lassen cc , the coach wants me" i feel it youll get more my nig no doubt']

# %%
clean_tokens = get_token_list(df, 'tweet_clean', freq=True)
# Out:
# ********** tweet_clean Summary **********
#
# Number of unique words = 14005
#       token  count
# 0         a   3718
# 1       the   3388
# 2         i   2893
# 3        to   2278
# 4       you   2182
# 5       and   2177
# 6     bitch   2073
# 7        in   1418
# 8        is   1351
# 9      that   1317
# 10       my   1249
# 11       of   1211
# 12       on   1013
# 13     like    986
# 14      for    968
# 15       me    961
# 16    trash    900
# 17       be    865
# 18       it    823
# 19     this    806
# 20  bitches    767
# 21     with    743
# 22     your    614
# 23      are    608
# 24      but    607

# %%
stopped_tokens = get_token_list(df, 'tweet_stopped', freq=True)
# Out:
# ********** tweet_stopped Summary **********
#
# Number of unique words = 13830
#       token  count
# 0     bitch   2073
# 1      like    986
# 2     trash    900
# 3   bitches    767
# 4      hoes    588
# 5     pussy    565
# 6       hoe    517
# 7       get    487
# 8       ass    458
# 9      fuck    418
# 10    nigga    398
# 11      got    393
# 12      lol    381
# 13     shit    352
# 14     bird    322
# 15     know    309
# 16      one    290
# 17  charlie    267
# 18     love    255
# 19       go    248
# 20   faggot    246
# 21    ain't    246
# 22   niggas    230
# 23   yellow    228
# 24  yankees    227

# %%
plot_wordcloud(stopped_tokens, 'Stopped Corpus');

# %%
hate_tokens = get_token_list(df.groupby('class').get_group('hate speech'), 'tweet_stopped', freq=True)
# Out:
# ********** tweet_stopped Summary **********
#
# Number of unique words = 3453
#       token  count
# 0     bitch    209
# 1    faggot    191
# 2      like    169
# 3     nigga    139
# 4       ass    138
# 5     white    127
# 6      fuck    121
# 7     trash    113
# 8    nigger    112
# 9   fucking     95
# 10      fag     76
# 11   niggas     76
# 12      get     69
# 13  faggots     62
# 14     shit     60
# 15   people     59
# 16  bitches     59
# 17     hate     58
# 18  niggers     56
# 19     hoes     55
# 20    pussy     49
# 21      lol     49
# 22      got     48
# 23      hoe     43
# 24       go     41

# %%
offensive_tokens = get_token_list(df.groupby('class').get_group('offensive'), 'tweet_stopped', freq=True)
# Out:
# ********** tweet_stopped Summary **********
#
# Number of unique words = 6595
#       token  count
# 0     bitch   1853
# 1   bitches    708
# 2      hoes    521
# 3      like    512
# 4     pussy    509
# 5       hoe    439
# 6       ass    317
# 7      fuck    297
# 8      shit    287
# 9       get    271
# 10    nigga    259
# 11      got    243
# 12    ain't    194
# 13      lol    185
# 14     know    181
# 15   niggas    154
# 16     love    139
# 17      bad    132
# 18      one    118
# 19       go    118
# 20  fucking    116
# 21       yo    114
# 22      man    110
# 23       ya    107
# 24     want    106

# %%
neither_tokens = get_token_list(df.groupby('class').get_group('neither'), 'tweet_stopped', freq=True)
# Out:
# ********** tweet_stopped Summary **********
#
# Number of unique words = 9547
#       token  count
# 0     trash    691
# 1      like    305
# 2      bird    304
# 3   charlie    261
# 4   yankees    225
# 5    yellow    218
# 6     birds    173
# 7       lol    147
# 8       get    147
# 9       one    133
# 10  colored    117
# 11   monkey    115
# 12   ghetto    113
# 13      got    102
# 14     good     95
# 15     know     90
# 16      new     89
# 17       go     89
# 18     love     86
# 19      day     85
# 20     game     85
# 21     want     83
# 22   people     82
# 23     make     82
# 24    would     81

# %%
plot_wordcloud(hate_tokens, 'Hate Speech');

# %%
plot_wordcloud(offensive_tokens, 'Offensive Language');

# %%
plot_wordcloud(neither_tokens, 'Neither');

# %% [markdown]
# # MODEL

# %% [markdown]
# # INTERPRET

# %% [markdown]
# # Conclusions/Recommendations
